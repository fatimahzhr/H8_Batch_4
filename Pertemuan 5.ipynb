# %% [markdown]
# # Pandas Intro

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# # Showing Basics Statistics

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
# # Exploring Your Dataset

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["team_id"] == "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
df.loc[df["team_id"] == "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
df.loc[df["team_id"] == "MNL", "date_game"].agg(("min", "max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df.loc[df["team_id"] == "BOS", "pts"].sum()
# Out:
# 626484

# %%
df.loc[df["team_id"] == "NYK", "pts"]. sum()
# Out:
# 582497

# %%
df["pts"]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %% [markdown]
# # Understanding Series Object

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenues = pd.Series(
    [4200,8000,6500],
    index= ["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"Kyoto" in city_employee_count
# Out:
# False

# %% [markdown]
# ## Accessing Series Elements

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues[2]
# Out:
# 6500

# %%
city_revenues["Tokyo"]
# Out:
# 6500

# %%
city_revenues[-3]
# Out:
# 4200

# %%
city_revenues[0:2]
# Out:
# Amsterdam    4200
# Toronto      8000
# dtype: int64

# %%
city_revenues["Toronto": ]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues[-1::-1]
# Out:
# Tokyo        6500
# Toronto      8000
# Amsterdam    4200
# dtype: int64

# %%
city_revenues[:: -2]
# Out:
# Tokyo        6500
# Amsterdam    4200
# dtype: int64

# %%
city_revenues[1:: ]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
# Using loc and iloc

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"],
    index=[1, 2, 3, 5, 8])

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
colors.loc[3]
# Out:
# 'blue'

# %%
colors.iloc[3]
# Out:
# 'green'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[-4]
# Out:
# 'purple'

# %% [markdown]
# # Understanding DataFrame Objects

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"revenue"in city_data
# Out:
# True

# %%
# axes = row n coloumns
# axes[0] = index = row (Rangeindex)
# axes[1] = columns = keys

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df.keys()
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# ## Accessing DataFrame Element

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Toronto"]
# Out:
# revenue           8000.0
# employee_count       NaN
# Name: Toronto, dtype: float64

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
city_data.iloc[1:2]
# Out:
#        revenue  employee_count
# Tokyo     6500             8.0

# %%
df.loc[0, "game_id"]
# Out:
# '194611010TRH'

# %%
toys = pd.DataFrame(
    {
        "name": ["ball", "rubik's cube"],
        "shape": ["sphere", "cube"]
        
    })

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
toys.name
# Out:
# 0            ball
# 1    rubik's cube
# Name: name, dtype: object

# %%
# Using loc and iloc

# %%
city_data.loc["Tokyo": ]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Tokyo"]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Amsterdam":"Tokyo"]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
city_data.loc[["Amsterdam","Tokyo"],["revenue", "employee_count"]]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
city_data.loc[["Amsterdam"], ["employee_count"]]
# Out:
#            employee_count
# Amsterdam             5.0

# %%
#pilih game antara label 1001 dan 1006 untuk elemen nama tim dan skor

# %%
df.loc[1001:1006, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#         fran_id   opp_fran  pts  opp_pts
# 1001  Baltimore   Capitols   72       85
# 1002      Stags    Celtics   97       77
# 1003    Celtics      Stags   77       97
# 1004     Knicks    Bombers   71       80
# 1005    Bombers     Knicks   80       71
# 1006   Warriors  Baltimore   83       71

# %% [markdown]
# # Querying Your Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df[df["year_id"] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
current_decade = df[df["year_id"] > 2010]

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
# Memilih baris dengan nilai yang bukan null
notes_available= df[df['notes'].notnull()]

# %%
notes_available
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
notes_available.shape
# Out:
# (5424, 23)

# %%
df[~df['notes'].isna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
# Memfilter kumpulan data dan semua game yang nama tim tuan rumahnya diakhiri dengan "ers"

# %%
ers = df[df['fran_id'].str.endswith("ers")]

# %%
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 7                1            0     PRO  Steamrollers  ...  41.540619     BOS
# ...

# %%
ers.shape
# Out:
# (27797, 23)

# %%
ers["fran_id"].nunique()
# Out:
# 9

# %%
ers["fran_id"].value_counts()
# Out:
# Lakers          6024
# Sixers          5644
# Pacers          4227
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Bombers          249
# Steamrollers     168
# Packers           72
# Name: fran_id, dtype: int64

# %%
# filter dengan banyak kondisi

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  ...  win_equiv  opp_id  opp_fran  \
# 1726            0     BLB  Baltimore  ...  38.557545     MNL    Lakers
# 4890            0     BLB  Baltimore  ...  25.797792     BOS   Celtics
# 4909            0     BLB  Baltimore  ...  24.876236     MNL    Lakers
# 5208            0     BLB  Baltimore  ...  19.579676     NYK    Knicks
# 5825            0     BLB  Baltimore  ...  20.736986     BOS   Celtics
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1221          611  194811200PRO   NBA        0     1949  11/20/1948
# 1255          628  194811270ROC   NBA        0     1949  11/27/1948
# 1293          647  194812040ROC   NBA        0     1949   12/4/1948
# 1449          725  194901040PRO   NBA        0     1949    1/4/1949
# 1726          864  194902260BLB   NBA        0     1949   2/26/1949
# ...           ...           ...   ...      ...      ...         ...
# 126269      63135  201505120HOU   NBA        0     2015   5/12/2015
# 126276      63139  201505140LAC   NBA        0     2015   5/14/2015
# 126284      63143  201505190GSW   NBA        0     2015   5/19/2015
# 126294      63148  201505240CLE   NBA        0     2015   5/24/2015
# 126297      63149  201505250HOU   NBA        0     2015   5/25/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "LAL")
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9744         4873  196010240LAL   NBA        0     1961  10/24/1960
# 9747         4874  196010250LAL   NBA        0     1961  10/25/1960
# 9778         4890  196011050LAL   NBA        0     1961   11/5/1960
# 9782         4892  196011060LAL   NBA        0     1961   11/6/1960
# 9786         4894  196011090LAL   NBA        0     1961   11/9/1960
# ...           ...           ...   ...      ...      ...         ...
# 125073      62537  201501290LAL   NBA        0     2015   1/29/2015
# 125301      62651  201502200LAL   NBA        0     2015   2/20/2015
# 125335      62668  201502220LAL   NBA        0     2015   2/22/2015
# 125450      62726  201503010LAL   NBA        0     2015    3/1/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
#
#         seasongame  is_playoffs team_id fran_id  ...  win_equiv  opp_id  \
# 9744             3            0     LAL  Lakers  ...  33.237518     NYK
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notna())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 68901            1     LAC  Clippers  ...  47.888252     UTA          Jazz
# 68903            1     LAL    Lakers  ...  39.395412     POR  Trailblazers
#
#        opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 68901      107  1647.5092  1638.4095              H            W  0.499125
# 68903      102  1655.1210  1670.3677              H            L  0.406874
#
#                                             notes
# 68901  at Anaheim, CA (Anaheim Convention Center)
# 68903                            at Las Vegas, NV
#
# [2 rows x 23 columns]

# %% [markdown]
# # Grouping and Aggregating

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.mean()
# Out:
# 6233.333333333333

# %%
city_revenues.std()
# Out:
# 1913.9836293274125

# %%
df.groupby("fran_id", sort=False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df.groupby(by="fran_id")["pts"].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df[df['year_id'] > 2010].groupby("fran_id")["pts"].sum()
# Out:
# fran_id
# Bucks           38901
# Bulls           42723
# Cavaliers       40371
# Celtics         41512
# Clippers        44908
# Grizzlies       43130
# Hawks           43167
# Heat            47815
# Hornets         37081
# Jazz            38705
# Kings           39439
# Knicks          40847
# Lakers          42040
# Magic           38780
# Mavericks       43754
# Nets            40347
# Nuggets         43048
# Pacers          43155
# Pelicans        38677
# Pistons         38089
# Raptors         39971
# Rockets         44309
# Sixers          39183
# Spurs           48162
# Suns            39934
# Thunder         48093
# Timberwolves    39387
# Trailblazers    41633
# Warriors        44937
# Wizards         40140
# Name: pts, dtype: int64

# %%
df[
    (df["fran_id"] == "Celtics") &
    (df["year_id"] > 2010)
].groupby(by=["year_id","team_id", "game_result"])["game_id"].count()
# Out:
# year_id  team_id  game_result
# 2011     BOS      L              30
#                   W              61
# 2012     BOS      L              36
#                   W              50
# 2013     BOS      L              44
#                   W              43
# 2014     BOS      L              57
#                   W              25
# 2015     BOS      L              46
#                   W              40
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(by=["year_id","is_playoffs"])["pts"].mean()
# Out:
# year_id  is_playoffs
# 2015     0              109.951220
#          1              103.285714
# Name: pts, dtype: float64

# %% [markdown]
# # Manipulating Columns

# %%
nba = df.copy()

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
print(nba.shape)
print(df.shape)
# Out:
# (126314, 23)
# (126314, 23)

# %%
nba['pts_diff'] = nba['pts'] - nba['opp_pts']

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba['pts_diff'].max()
# Out:
# 68

# %%
nba['pts_diff'].min()
# Out:
# -68

# %%
nba["pts_diff_abs"] = np.abs(nba["pts_diff"])

# %%
nba[nba["pts_diff_abs"] == nba["pts_diff_abs"].min()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 32             17  194611090STB   NBA        0     1947   11/9/1946
# 33             17  194611090STB   NBA        1     1947   11/9/1946
# 70             36  194611200DTF   NBA        1     1947  11/20/1946
# 71             36  194611200DTF   NBA        0     1947  11/20/1946
# 82             42  194611220TRH   NBA        1     1947  11/22/1946
# ...           ...           ...   ...      ...      ...         ...
# 126073      63037  201504110ORL   NBA        0     2015   4/11/2015
# 126270      63136  201505130ATL   NBA        0     2015   5/13/2015
# 126271      63136  201505130ATL   NBA        1     2015   5/13/2015
# 126288      63145  201505210GSW   NBA        0     2015   5/21/2015
# 126289      63145  201505210GSW   NBA        1     2015   5/21/2015
#
#         seasongame  is_playoffs team_id   fran_id  ...  opp_fran  opp_pts  \
# 32               4            0     STB   Bombers  ...  Capitols       69
# ...

# %%
nba.rename(
    columns={"game_result": "result", "game_location": "location"}, inplace=True)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...   opp_fran  opp_pts  \
# 0                1            0     TRH    Huskies  ...     Knicks       68
# ...

# %%
# Menghapus kolom elo
elo_coloumns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'location', 'result', 'forecast', 'notes', 'pts_diff',
#         'pts_diff_abs'],
#        dtype='object')]

# %%
nba.drop(elo_coloumns, axis=1, inplace=True )

# %%
nba.shape
# Out:
# (126314, 21)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  object
#  16  result        126314 non-null  object
# ...

# %%
nba['location'].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %%
nba["location"].nunique()
# Out:
# 3

# %%
nba["location"] = pd.Categorical(nba["location"])

# %%
nba['location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba["pts_diff"] = nba["pts_diff"].astype(np.float64)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_without_missing_data = nba.dropna(axis=1)

# %%
nba_without_missing_data.shape
# Out:
# (126314, 20)

# %%
nba_without_missing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_with_default_notes = nba.copy()

# %%
nba_with_default_notes["notes"].fillna(
    value="no notes",
    inplace=True)

# %%
nba_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba_with_default_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_with_default_notes["notes"].describe()
# Out:
# count       126314
# unique         232
# top       no notes
# freq        120890
# Name: notes, dtype: object

# %% [markdown]
# # Invalid Values

# %%
nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts      win_equiv        opp_pts  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982      41.707889     102.729982
# std         0.244499      14.814845      10.627332      14.814845
# min         0.000000       0.000000      10.152501       0.000000
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 26684           7            0     DNR  Nuggets  ...  40.408863     VIR
#
#       opp_fran opp_pts  location result  forecast  \
# 26684  Squires       2         A      L  0.328948
#
#                                 notes pts_diff  pts_diff_abs
# 26684  at Richmond VA; forfeit to VIR     -2.0             2
#
# [1 rows x 21 columns]

# %%
nba.drop(26684, axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %% [markdown]
# # Inconsistent Values

# %%
nba[(nba["pts"] > nba["opp_pts"])]["result"].value_counts()
# Out:
# W    63157
# Name: result, dtype: int64

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["result"] != 'L')].empty
# Out:
# True

# %% [markdown]
# # Combining Multiple Datasets

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
another_city_data = pd.DataFrame(
    {
    "revenue": [4500, 8000],
    "employee_count": [2,2]
    }
    ,index=["New York", "Barcelona"]
)

# %%
another_city_data
# Out:
#            revenue  employee_count
# New York      4500               2
# Barcelona     8000               2

# %%
all_city_data = pd.concat([city_data,another_city_data])

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      4500             2.0
# Barcelona     8000             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1,1,0,0,0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    4500.0             2.0      NaN      NaN
# Barcelona   8000.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     8000             2.0    Spain        0

# %%
all_city_data.merge(city_countries, left_index=True, right_index=True)
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     8000             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population": [17,127,37],
    "continent": ["Europe", "Asia", "North America"]},
    index=["Holland", "Japan", "Canada"])

# %%
countries
# Out:
#          population      continent
# Holland          17         Europe
# Japan           127           Asia
# Canada           37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    4500.0             2.0      NaN      NaN
# Barcelona   8000.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(left=cities, right=countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population  \
# Amsterdam   4200.0             5.0  Holland      1.0          17
# Rotterdam      NaN             NaN  Holland      0.0          17
# Tokyo       6500.0             8.0    Japan      1.0         127
# Toronto     8000.0             NaN   Canada      0.0          37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
cities.merge(right=countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population  \
# Amsterdam   4200.0             5.0  Holland      1.0          17
# Rotterdam      NaN             NaN  Holland      0.0          17
# Tokyo       6500.0             8.0    Japan      1.0         127
# Toronto     8000.0             NaN   Canada      0.0          37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left")
# Out:
#            revenue  employee_count  country  capital  population  \
# Amsterdam   4200.0             5.0  Holland      1.0        17.0
# Tokyo       6500.0             8.0    Japan      1.0       127.0
# Toronto     8000.0             NaN   Canada      0.0        37.0
# New York    4500.0             2.0      NaN      NaN         NaN
# Barcelona   8000.0             2.0    Spain      0.0         NaN
# Rotterdam      NaN             NaN  Holland      0.0        17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# # Visualizing Pandas Dataframe

# %%
# %matplotlib inline

# %%
nba[nba["fran_id"] == "Warriors"].groupby("year_id")["pts"].mean().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Warriors"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Warriors"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947     4871
# 1948     4453
# 1949     5170
# 1950     5112
# 1951     5801
#         ...
# 2011     8477
# 2012     6453
# 2013     9528
# 2014     9294
# 2015    11185
# Name: pts, Length: 69, dtype: int64

# %%
nba["fran_id"].value_counts().head(7).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts().head(7)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Name: fran_id, dtype: int64
