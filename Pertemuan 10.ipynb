# %% [markdown]
# # Inferential Statistics

# %%
import pandas as pd
import numpy as np
import scipy.stats

# %matplotlib inline

import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image
import matplotlib as mpl
import seaborn as sns


sns.set(color_codes = True)
sns.set(rc={'figure.figsize': (5,5)})
from scipy.stats import uniform

# %% [markdown]
# ## Uniform Distribution

# %%
# random num from uniform distribution
uniform_data = scipy.stats.uniform.rvs(loc=10, scale = 2, size=1000)
ax = sns.distplot(uniform_data,
                 bins=100,
                 kde=True,
                 color='darkblue',
                 hist_kws={"linewidth":15, 'alpha':1})
# Out:
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/1181216156.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(uniform_data,

# %% [markdown]
# ## Normal Distribution

# %%
from scipy.stats import norm
normal_data = scipy.stats.norm.rvs(size=10000, loc=0, scale=1)
ax = sns.distplot(normal_data,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth":15, 'alpha':1})
# Out:
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/694866572.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(normal_data,

# %% [markdown]
# ## Gamma Distribution

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5, size=10000)

# %%
ax = sns.displot(data_gamma,
               kde=True,
               bins=100,
               color='skyblue',
               linewidth= 15,
               alpha = 1)
ax.set(xlabel = 'Gamma Distribution', ylabel='Frequency')

# %% [markdown]
# ## Exponential Distribution

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1, loc=0, size=1000)

# %%
ax = sns.distplot(data_expon,
                 kde=True,
                 bins=100,
                 color='darkblue',
                 hist_kws={"linewidth":15, 'alpha':1})
ax.set(xlabel = 'Exponential Distribution', ylabel='Frequency')
# Out:
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/4243296194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_expon,
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ## Poisson Distribution

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
ax = sns.distplot(data_poisson,
                 bins=30,
                 kde=False,
                 hist_kws={"linewidth":15, 'alpha':1})
ax.set(xlabel = 'Poisson Distribution', ylabel='Frequency')
# Out:
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/1060028075.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_poisson,
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ## Binomial Distribution

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10, p=0.8, size=10000)

# %%
ax = sns.displot(data_binom,
                 kde=False,
                 color = 'cornflowerblue',
                 linewidth = 15,
                 alpha = 1)
ax.set(xlabel = 'Poisson Distribution', ylabel='Frequency')

# %% [markdown]
# ## Bernoulli Distribution

# %%
from scipy.stats import bernoulli
data_bernoulli = bernoulli.rvs(size=10000, p=0.6)

# %%
ax = sns.displot(data_bernoulli,
                 kde=False,
                 color = 'cornflowerblue',
                 linewidth = 15,
                 alpha = 1)
ax.set(xlabel = 'Poisson Distribution', ylabel='Frequency')

# %% [markdown]
# ## Confidence Intervals

# %% [markdown]
# ### CI for Pupulation Mean

# %%
data_normal = scipy.stats.norm.rvs(loc=0, scale=1, size=200)

# %%
means_of_means = []
for experiment in range(1000):
   resampled = np.random.choice(data_normal,size= len(data_normal), replace=True)
   means_of_means.append(np.mean(resampled))

# %%
len(means_of_means)
# Out:
# 1000

# %%
np.mean(means_of_means)
# Out:
# 0.03239670509097998

# %%
lower_bound = np.quantile(means_of_means, 0.025)
upper_bound = np.quantile(means_of_means, 0.975)

# %%
print("95% CI of Population Mean: ({}, {})".format(lower_bound, upper_bound))
# Out:
# 95% CI of Population Mean: (-0.10778606708238288, 0.16337946147068744)

# %%
np.std(means_of_means)
# Out:
# 0.06982278500736835

# %%
lower_bound = np.mean(means_of_means) - np.std(means_of_means)*1.96
upper_bound = np.mean(means_of_means) + np.std(means_of_means)*1.96
print("95% CI of Population Mean: ({}, {})".format(lower_bound, upper_bound))
# Out:
# 95% CI of Population Mean: (-0.10445595352346201, 0.16924936370542196)

# %% [markdown]
# ### Using Formula

# %%
def standar_error_of_mean(data):
    s = np.std(data)
    nobs = len(data)
    return s/nobs**0.5

# %%
se = standar_error_of_mean(data_normal)
m = np.mean(data_normal)

# %%
lower_bound = m - se*1.96
upper_bound = m + se*1.96
print("95% CI of Population Mean: ({}, {})".format(lower_bound, upper_bound))
# Out:
# 95% CI of Population Mean: (-0.10398696437813318, 0.1677653366171313)

# %% [markdown]
# ### CI for Population Proportion

# %%
heart_data = pd.read_csv('/Users/apple/Downloads/heart.csv')
heart_data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
# Construct a CI for the female population proportion that has heart disease

# %%
heart_data['Sex'] = heart_data.sex.replace({1:'Male', 0:'Female'})

# %%
heart_disease = heart_data[['target', 'Sex']].dropna()

# %%
pd.crosstab(heart_disease.target, heart_disease.Sex)
# Out:
# Sex     Female  Male
# target
# 0           86   413
# 1          226   300

# %%
# Jumlah wanita penderita sakit jantung = 226

# %%
# Proporsi penduduk wanita yang menderita sakit jantung
p_fm = 226/(86+226)
p_fm
# Out:
# 0.7243589743589743

# %%
# Populasi wanita
n = 86 + 226
n
# Out:
# 312

# %%
# standard error
se_female = np.sqrt(p_fm * (1-p_fm)/n)
se_female
# Out:
# 0.02529714756803247

# %%
# CI dengan z-score 1.96, confidence = 95%
z_score = 1.96
lcb = p_fm - z_score * se_female # lower limit of CI
ucb = p_fm + z_score * se_female # Upper limit of CI
lcb, ucb
# Out:
# (0.6747765651256307, 0.773941383592318)

# %%
import statsmodels.api as sm
sm.stats.proportion_confint(n * p_fm, n)
# Out:
# (0.6747774762140357, 0.773940472503913)

# %% [markdown]
# ### CI of Mean

# %%
heart_data.groupby('Sex').agg({'chol': [np.mean, np.std, np.size]})
# Out:
#               chol
#               mean        std size
# Sex
# Female  261.455128  64.466781  312
# Male    239.237027  43.155535  713

# %%
# Mengekstrak parameter yg diperlukan hanya untuk populasi wanita
mean_female = 261.45 #mean cholesterol of female
sd = 64.46 #std for female population
n = 312 #female population
z = 1.96

# %%
se = sd / np.sqrt(n)

# %%
# CI
lcb = mean_female - z * se 
ucb = mean_female + z * se
lcb, ucb
# Out:
# (254.29731539314585, 268.60268460685415)

# %% [markdown]
# ## Hypothesis Testing

# %%
import statsmodels.api as sm

# %% [markdown]
# p = adalah proporsi orang tua (52%) yang percaya elektronik menjadi penyebab kurang tidur remaja, apa saat ini semakin banyak ortu yang percaya akan hal tsb?
#
# H0: p = 0.52
#
# H1: p > 0.52
#
# Data: 1018 orang disurvey, 56% percaya elektronik menjadi penyebab kurang tidur remaja
#
# alpha = 0.05
#
# - p-value > alpha --> Fail to Reject H0
#
# - p-value <= alpha --> Reject H0

# %%
n_obs = 1018
pnull = 0.52
pnew = 0.56

# %%
sm.stats.proportions_ztest(pnew*n_obs,nobs=n_obs,value=pnull,alternative='larger')
# Out:
# (2.571067795759113, 0.005069273865860533)

# %%
# p-value < 0.05 --- Reject H0

# %% [markdown]
# ### Difference of Means

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nhanes_2015_2016.csv")
data.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %% [markdown]
# H0:  μ1 = μ2
#
# H1: μ1 != μ2
#
# Data:
# - 2976 females
# - μ1 = 29.94
# - σ1= 7.75
#
# -2759 males
# - μ2 = 28.78
# - σ2 = 6.25
#
# μ1-μ2 = 1.16
#
# ztest
#
# alpha = 0.05

# %%
females = data[data["RIAGENDR"] == 2]
males = data[data["RIAGENDR"] == 1]

# %%
nf = len(females)
meanf = females["BMXBMI"].mean()
sdf = females["BMXBMI"].std()

print(nf, meanf, sdf)
# Out:
# 2976 29.93994565217392 7.753318809545674

# %%
nm = len(males)
meanm = males["BMXBMI"].mean()
sdm = males["BMXBMI"].std()

print(nm, meanm, sdm)
# Out:
# 2759 28.778072111846942 6.2525676168014614

# %%
sm.stats.ztest(females["BMXBMI"].dropna(), males["BMXBMI"].dropna(),alternative='two-sided')
# Out:
# (6.1755933531383205, 6.591544431126401e-10)

# %%
p_val = 6.591544431126401e-10

# %%
p_val < 0.05
# Out:
# True

# %%
sns.distplot(females["BMXBMI"].dropna(),label="Female BMI")
sns.distplot(males["BMXBMI"].dropna(),label="Males BMI")
plt.legend()
# Out:
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/3820271487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(females["BMXBMI"].dropna(),label="Female BMI")
# /var/folders/xy/xy312wfd7rl3ln2c6qntrhdr0000gn/T/ipykernel_25167/3820271487.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(males["BMXBMI"].dropna(),label="Males BMI")

# %% [markdown]
# ### T-test

# %%
scipy.stats.ttest_ind(a=females["BMXBMI"].dropna(),
                       b=males["BMXBMI"].dropna(),
                       alternative='two-sided')
# Out:
# Ttest_indResult(statistic=6.175593353138321, pvalue=7.050275578094527e-10)

# %%
sample1 = scipy.stats.norm.rvs(loc=0.1, scale=1, size=10000)
sample2 = scipy.stats.norm.rvs(loc=0.15, scale=1, size=10000)

p = scipy.stats.ttest_ind(a=sample1,b=sample2, alternative='two-sided').pvalue

if p > 0.05:
    print("Probably From same distribution")
else:
    print("Probably diffrent distribution")
# Out:
# Probably diffrent distribution

# %% [markdown]
# ### Chi-Squared

# %% [markdown]
# H0: var1 tidak ada hubungan dengan var2
#
# H1: ada hubungan antara dua variable

# %%
data= [
    [90,120,60],
    [70,100,60]
]

# %%
p = scipy.stats.chi2_contingency(data).pvalue

if p > 0.05:
    print("Probably Independent")
else:
    print("Probably Dependent")
# Out:
# Probably Independent
